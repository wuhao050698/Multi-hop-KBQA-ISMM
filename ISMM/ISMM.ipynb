# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/5002/Multi-hopQA/code
# Out:
# /content/drive/MyDrive/5002/Multi-hopQA/code

# %%
import pickle
with open('../trained_model/MetaQA_half/config.pkl', 'rb') as f:
  args = pickle.load(f)

# %%
args
# Out:
# Namespace(batch=1, beam=3, dev_q='../data/mix-hop/MetaQA/qa_dev.txt', dropout=0.0, embedding='/home/yunshi/Word2vec/glove.840B.300d.zip', hidden_dimension=200, is_train=0, kb_file='../data/mix-hop/MetaQA/kb_half.txt', learning_rate=0.0001, load_id='_Acc', max_epochs=20, max_hop=3, only_eval=0, save_id='_Acc', task='../trained_model/MetaQA', test_q='../data/mix-hop/MetaQA/qa_test.txt', threshold=0.5, train_q='../data/mix-hop/MetaQA/qa_train.txt')

# %%
args.dev_q = '../data/mix-hop/MetaQA/half/qa_dev.txt'
args.kb_file = '../data/mix-hop/MetaQA/half/kb_half.txt'
args.test_q = '../data/mix-hop/MetaQA/half/qa_test.txt'
args.train_q = '../data/mix-hop/MetaQA/half/qa_train.txt'
args.task = '../trained_model/MetaQA_half'

# %%
args
# Out:
# Namespace(batch=1, beam=3, dev_q='../data/mix-hop/MetaQA/half/qa_dev.txt', dropout=0.0, embedding='/home/yunshi/Word2vec/glove.840B.300d.zip', hidden_dimension=200, is_train=0, kb_file='../data/mix-hop/MetaQA/half/kb_half.txt', learning_rate=0.0001, load_id='_Acc', max_epochs=20, max_hop=3, only_eval=0, save_id='_Acc', task='../trained_model/MetaQA_half', test_q='../data/mix-hop/MetaQA/half/qa_test.txt', threshold=0.5, train_q='../data/mix-hop/MetaQA/half/qa_train.txt')

# %%
with open('../trained_model/MetaQA_half/config.pkl', 'wb') as f:
  pickle.dump(args, f)

# %%
with open('../trained_model/MetaQA_half/config.pkl', 'rb') as f:
  args = pickle.load(f)
args
# Out:
# Namespace(batch=1, beam=3, dev_q='../data/mix-hop/MetaQA/half/qa_dev.txt', dropout=0.0, embedding='/home/yunshi/Word2vec/glove.840B.300d.zip', hidden_dimension=200, is_train=0, kb_file='../data/mix-hop/MetaQA/half/kb_half.txt', learning_rate=0.0001, load_id='_Acc', max_epochs=20, max_hop=3, only_eval=0, save_id='_Acc', task='../trained_model/MetaQA_half', test_q='../data/mix-hop/MetaQA/half/qa_test.txt', threshold=0.5, train_q='../data/mix-hop/MetaQA/half/qa_train.txt')

# %%
# %pwd
# Out:
# '/content/drive/My Drive/5002/Multi-hopQA/code'

# %%
# !wget http://nlp.stanford.edu/data/glove.840B.300d.zip
# Out:
# --2021-04-19 16:23:05--  http://nlp.stanford.edu/data/glove.840B.300d.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.840B.300d.zip [following]
# --2021-04-19 16:23:05--  https://nlp.stanford.edu/data/glove.840B.300d.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.840B.300d.zip [following]
# --2021-04-19 16:23:05--  http://downloads.cs.stanford.edu/nlp/data/glove.840B.300d.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !python Multi-hopKBQA_runner.py --task 0
# Out:
# Train and test for task  ...
# read kb ... 0
# pretrained vocab 19917 among 27874
# train: 98483 dev: 11825 test: 11710
# Parser Arguments
# task: 0
# embedding: /content/drive/MyDrive/5002/Multi-hopQA/code/glove.840B.300d.zip
# save_id: _Acc_tmp
# load_id: _Acc_tmp
# train_q: /content/drive/MyDrive/5002/Multi-hopQA/data/mix-hop/MetaQA/half/qa_train.txt
# dev_q: /content/drive/MyDrive/5002/Multi-hopQA/data/mix-hop/MetaQA/half/qa_dev.txt
# test_q: /content/drive/MyDrive/5002/Multi-hopQA/data/mix-hop/MetaQA/half/qa_test.txt
# kb_file: /content/drive/MyDrive/5002/Multi-hopQA/data/mix-hop/MetaQA/half/kb_half.txt
# max_epochs: 5
# batch: 1
# learning_rate: 0.0001
# dropout: 0.0
# hidden_dimension: 200
# is_train: 1
# only_eval: 0
# max_hop: 3
# beam: 3
# threshold: 0.5
# load_save: ../trained_model/MetaQA_half
# fail to load pre-trained parameters ...
# Evaluation ...
# 1 | train loss 1.03466(1.03466)(1.03469) | train eval: 0.201918  | val eval: 0.253767  | test eval: 0.259625
# ...

# %%
# !python Multi-hopKBQA_runner.py --task 3 --load_save '../trained_model/MetaQA_half' --max_epoch 10
# Out:
# Train and test for task  ...
# train: 98483 dev: 11825 test: 11710
# Parser Arguments
# task: ../trained_model/MetaQA_half
# embedding: /home/yunshi/Word2vec/glove.840B.300d.zip
# save_id: _Acc
# load_id: _Acc
# train_q: ../data/mix-hop/MetaQA/half/qa_train.txt
# dev_q: ../data/mix-hop/MetaQA/half/qa_dev.txt
# test_q: ../data/mix-hop/MetaQA/half/qa_test.txt
# kb_file: ../data/mix-hop/MetaQA/half/kb_half.txt
# max_epochs: 20
# batch: 1
# learning_rate: 0.0001
# dropout: 0.0
# hidden_dimension: 200
# is_train: 1
# only_eval: 0
# max_hop: 3
# beam: 3
# threshold: 0.5
# successfully load pre-trained parameters ...
# Evaluation ...
# 1 | train loss 0.855969(0.855969)(0.855964) | train eval: 0.250441  | val eval: 0.244896  | test eval: 0.249536
# Evaluation ...
# 2 | train loss 0.758823(0.758823)(0.758828) | train eval: 0.262675  | val eval: 0.252675  | test eval: 0.257878
# Evaluation ...
# ...
